# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import os
import numpy as np
import pandas as pd
import rpy2
from rpy2.robjects.packages import importr

# %%
# import R's "base" package
base = importr('base')

# import R's "utils" package
utils = importr('utils')

# select a mirror for R packages
utils.chooseCRANmirror(ind=1) # select the first mirror in the list
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x1072abed0> [0]

# %%
#install R packages
#utils.install_packages("ggplot2")
# Out:
# R[write to console]: also installing the dependencies ‘lattice’, ‘colorspace’, ‘nlme’, ‘Matrix’, ‘farver’, ‘labeling’, ‘munsell’, ‘RColorBrewer’, ‘viridisLite’, ‘gtable’, ‘isoband’, ‘MASS’, ‘mgcv’, ‘scales’
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/lattice_0.21-8.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 589330 bytes (575 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 575 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/colorspace_2.1-0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2116339 bytes (2.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.0 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/nlme_3.1-163.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 848981 bytes (829 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 829 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/Matrix_1.6-1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2064299 bytes (2.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.0 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/farver_2.1.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1274363 bytes (1.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.2 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/labeling_0.4.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 10156 bytes
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 10156 bytes
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/munsell_0.5.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 182653 bytes (178 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 178 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/RColorBrewer_1.1-3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 11638 bytes (11 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 11 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/viridisLite_0.4.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1267121 bytes (1.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.2 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/gtable_0.3.4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 130100 bytes (127 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 127 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/isoband_0.2.7.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1591812 bytes (1.5 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.5 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/MASS_7.3-60.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 561534 bytes (548 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 548 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/mgcv_1.9-0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1112050 bytes (1.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.1 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/scales_1.2.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 270609 bytes (264 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 264 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/ggplot2_3.4.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2190947 bytes (2.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.1 MB
#
#
# * installing *source* package ‘lattice’ ...
# ** package ‘lattice’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘clang version 16.0.6’
# using SDK: ‘MacOSX13.3.sdk’
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c init.c -o init.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c threeDplot.c -o threeDplot.o
# x86_64-apple-darwin13.4.0-clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -o lattice.dylib init.o threeDplot.o -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -lR -Wl,-framework -Wl,CoreFoundation
# ld: warning: -pie being ignored. It is only used when linking a main executable
# installing to /Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/library/00LOCK-lattice/00new/lattice/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** demo
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (lattice)
# * installing *source* package ‘colorspace’ ...
# ** package ‘colorspace’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘clang version 16.0.6’
# using SDK: ‘MacOSX13.3.sdk’
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c colorspace.c -o colorspace.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c init.c -o init.o
# x86_64-apple-darwin13.4.0-clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -o colorspace.dylib colorspace.o init.o -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -lR -Wl,-framework -Wl,CoreFoundation
# ld: warning: -pie being ignored. It is only used when linking a main executable
# installing to /Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/library/00LOCK-colorspace/00new/colorspace/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** demo
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (colorspace)
# * installing *source* package ‘farver’ ...
# ** package ‘farver’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘clang version 16.0.6’
# using C++11
# using SDK: ‘MacOSX13.3.sdk’
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c ColorSpace.cpp -o ColorSpace.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c Comparison.cpp -o Comparison.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c Conversion.cpp -o Conversion.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c encode.cpp -o encode.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c farver.cpp -o farver.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c init.cpp -o init.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -o farver.dylib ColorSpace.o Comparison.o Conversion.o encode.o farver.o init.o -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -lR -Wl,-framework -Wl,CoreFoundation
# ld: warning: -pie being ignored. It is only used when linking a main executable
# installing to /Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/library/00LOCK-farver/00new/farver/libs
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (farver)
# * installing *source* package ‘labeling’ ...
# ** package ‘labeling’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (labeling)
# * installing *source* package ‘RColorBrewer’ ...
# ** package ‘RColorBrewer’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (RColorBrewer)
# * installing *source* package ‘viridisLite’ ...
# ** package ‘viridisLite’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (viridisLite)
# * installing *source* package ‘gtable’ ...
# ** package ‘gtable’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (gtable)
# * installing *source* package ‘isoband’ ...
# ** package ‘isoband’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘clang version 16.0.6’
# using C++11
# using SDK: ‘MacOSX13.3.sdk’
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c clip-lines.cpp -o clip-lines.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c init.cpp -o init.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c isoband.cpp -o isoband.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c polygon.cpp -o polygon.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c separate-polygons.cpp -o separate-polygons.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c test-clip-lines.cpp -o test-clip-lines.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c test-runner.cpp -o test-runner.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c test-separate-polygons.cpp -o test-separate-polygons.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -o isoband.dylib clip-lines.o init.o isoband.o polygon.o separate-polygons.o test-clip-lines.o test-runner.o test-separate-polygons.o -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -lR -Wl,-framework -Wl,CoreFoundation
# ld: warning: -pie being ignored. It is only used when linking a main executable
# installing to /Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/library/00LOCK-isoband/00new/isoband/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (isoband)
# * installing *source* package ‘MASS’ ...
# ** package ‘MASS’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘clang version 16.0.6’
# using SDK: ‘MacOSX13.3.sdk’
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c MASS.c -o MASS.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c lqs.c -o lqs.o
# x86_64-apple-darwin13.4.0-clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -o MASS.dylib MASS.o lqs.o -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -lR -Wl,-framework -Wl,CoreFoundation
# ld: warning: -pie being ignored. It is only used when linking a main executable
# installing to /Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/library/00LOCK-MASS/00new/MASS/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (MASS)
# * installing *source* package ‘nlme’ ...
# ** package ‘nlme’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘clang version 16.0.6’
# using Fortran compiler: ‘GNU Fortran (GCC) 12.3.0’
# using SDK: ‘MacOSX13.3.sdk’
# x86_64-apple-darwin13.4.0-gfortran  -fPIC  -march=core2 -mtune=haswell -ftree-vectorize -fPIC -fstack-protector -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c chol.f -o chol.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include    -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c corStruct.c -o corStruct.o
# ...
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (munsell)
# * installing *source* package ‘mgcv’ ...
# ** package ‘mgcv’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘clang version 16.0.6’
# using SDK: ‘MacOSX13.3.sdk’
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c coxph.c -o coxph.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c davies.c -o davies.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c discrete.c -o discrete.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c gdi.c -o gdi.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c init.c -o init.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c magic.c -o magic.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c mat.c -o mat.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c matrix.c -o matrix.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c mgcv.c -o mgcv.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c misc.c -o misc.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c mvn.c -o mvn.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c ncv.c -o ncv.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c qp.c -o qp.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c soap.c -o soap.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c sparse-smooth.c -o sparse-smooth.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c sparse.c -o sparse.o
# x86_64-apple-darwin13.4.0-clang -I"/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/include" -DNDEBUG   -D_FORTIFY_SOURCE=2 -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -mmacosx-version-min=10.9 -I/Users/sebastiansciarra/anaconda3/envs/ds_project/include   -fopenmp -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/sebastiansciarra/anaconda3/envs/ds_project/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/work=/usr/local/src/conda/r-base-4.3.1 -fdebug-prefix-map=/Users/sebastiansciarra/anaconda3/envs/ds_project=/usr/local/src/conda-prefix  -c tprs.c -o tprs.o
# x86_64-apple-darwin13.4.0-clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib -o mgcv.dylib coxph.o davies.o discrete.o gdi.o init.o magic.o mat.o matrix.o mgcv.o misc.o mvn.o ncv.o qp.o soap.o sparse-smooth.o sparse.o tprs.o -llapack -lblas -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/gcc/x86_64-apple-darwin13.4.0/12.2.0 -L/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/_build_env/lib -lgfortran -lquadmath -lm -fopenmp -L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/lib -lR -Wl,-framework -Wl,CoreFoundation
# ld: warning: directory not found for option '-L/Users/sebastiansciarra/anaconda3/envs/ds_project/lib/gcc/x86_64-apple-darwin13.4.0/12.2.0'
# ld: warning: directory not found for option '-L/Users/runner/miniforge3/conda-bld/r-base-split_1689933286882/_build_env/lib'
# ld: warning: -pie being ignored. It is only used when linking a main executable
# installing to /Users/sebastiansciarra/anaconda3/envs/ds_project/lib/R/library/00LOCK-mgcv/00new/mgcv/libs
# ** R
# ** data
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (mgcv)
# * installing *source* package ‘scales’ ...
# ** package ‘scales’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (scales)
# * installing *source* package ‘ggplot2’ ...
# ** package ‘ggplot2’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (ggplot2)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/private/var/folders/jd/040j2c_s7jlgd0tqzr3lqptc0000gn/T/RtmpeYLRFY/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Updating HTML index of packages in '.Library'
#
# R[write to console]: Making 'packages.html' ...
# R[write to console]:  done
# <rpy2.rinterface_lib.sexp.NULLType object at 0x110748dd0> [0]

# %%
# %%R
# library(ggplot2)
# gg

# %%
# %%R
# dat <- data.frame(x = 2, y = 3)

# %%
# %%R
# ggplot(data = daat, mapping =
